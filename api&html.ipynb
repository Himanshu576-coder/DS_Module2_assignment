# %% [markdown]
# # API
# API stands for Application Programming Interface, allows interaction between two software components.
#
# An example is one has some data. You have a set of software components. We use the pandas API to process the data by communicating with the other software components. Let’s clean up the diagram. When you create a dictionary, and then create a pandas (**Pandas is an API**) object with the DataFrame constructor, in API lingo, this is an “instance.” The data in the dictionary is passed along to the pandas API. You then use the dataframe to communicate with the API.
#
# When you call the method `head` the dataframe communicates with the API displaying the first few rows of the dataframe in th following code.

# %%
import pandas as pd
import matplotlib.pyplot as plt

new_dict = {'a':[1,2,6] , 'b':[2,5,7]} 
data = pd.DataFrame(new_dict)
data.head()  
data.mean()
# Out:
# a    3.000000
# b    4.666667
# dtype: float64

# %% [markdown]
# # REST APIs
# RESt stands for REpresentational State Transfer APIs. REST APIs are used to interact with web services via HTTP (Hyoertext Transfer Protocol). HTTP is a method to transmit data over the internet, and the HTTP message usually containes a JSON file. It containes instructions of the operations one wants to perform, and the API returns a response via HTTP in the form of a JSON file generally. Here the APIs communicating work as the **client** that asks for the info and **server** processing the client's request.
#
#
# ### URL
# Uniform resource locator or URL has three components:
#
# - Scheme: the protocol, which is always http://
# - Internet address, such as www.ibm.com
# - Route, which points the location on the web server, such as C:/users/himan/machinelearning.pdf

# %% [markdown]
# ## Request and Response process
#
# Client's request and Server responses in status codes which have the following meaning:
# |Status code | Meaning |
# |-----------|------------|
# |1XX| Everything so far is OK|
# |2XX| Success |
# |3XX| Redirecting|
# |4XX| Client Error|
# |401|Unauthorised|
# |403|Forbidden|
# |404|Not Found|
# |500|Server Error|

# %% [markdown]
# ## Some terminologies
#
# **Webscraping** : Web scraping, also known as web harvesting or web data extraction, is the process of extracting information from websites or web pages. It involves automated retrieval of data from web sources.
#
# **Parsing** : Parsing involves breaking down the HTML structure into components, such as tags, attributes, and text content.

# %%
# %pip install requests

# %%
# %pip install beautifulsoup4

# %%
# %pip install lxml

# %% [markdown]
# # HTML Basics
#
# ## Sample html code:
#
# <code>`<!DOCTYPE html>`</code>
#
# `<html>`
#
# `<body>`
#
# `<h1>My First Heading</h1>`
#
# `<p>My first paragraph.</p>`
#
# `</body>`
#
# `</html>`</code>
#
# Hypertext markup language (HTML) serves as the foundation of web pages. Understanding its structure is crucial for web scraping.
#
# - `<html>` is the root element of an HTML page.
# - `<head>` contains meta-information about the HTML page.
# - `<body>` displays the content on the web page, often the data of interest.
# - `<h3>` tags are type 3 headings, making text larger and bold. It starts with `<h1>` which is the largest to `<h6>` with the smallest heading
# - `<p>` tags represent paragraphs.

# %% [markdown]
# ### HTML Tags
# HTML tags define the structure of web content and can contain attributes.
#
# An HTML tag consists of an opening (start) tag and a closing (end) tag, such as `<html>` at start and `</html>` at the end .
# Tags have names (`<a>` for an anchor tag). Tags may contain attributes with an attribute name and value, providing additional information to the tag.
#
# ### Working on HTML table
# <br>
#
# These are the following tags which are used while creating HTML tables.
#
# * `<table>`: This tag is a root tag used to define the start and end of the table. All the content of the table is enclosed within these tags.
#
# * `<tr>`: This tag is used to define a table row. Each row of the table is defined within this tag.
#
# * `<td>`: This tag is used to define a table cell. Each cell of the table is defined within this tag. You can specify the content of the cell between the opening and closing `<td>` tags.
#
# * `<th>`: This tag is used to define a header cell in the table. The header cell is used to describe the contents of a column or row. By default, the text inside a `<th>` tag is bold and centered.
#
# * `<tbody>`: This is the main content of the table, which is defined using the `<tbody>` tag. It contains one or more rows of `<tr>` elements.
#
# Find more on html [here](https://www.w3schools.com/html/html_intro.asp)

# %% [markdown]
# ### The code that doesn't work
#
# <code>
# import pandas as pd
# url = 'https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)'
# tables = pd.read_html(url)
# d = tables[2]
# print(d)
# </code>
#
# Displays error 403: forbidden access. Happens because wikipedia does not allow automated access to its webpages through certain environments. There is the BeautifulSoup APi that helps in circumventing this error, so we study it now.
#
# **Note: BeautifulSoup is the default library to extract any information from web pages**

# %% [markdown]
# ## BeautifulSoup and Requests
#
# BeautifulSoup is a Python library that helps in getting data out of HTML and XML files. The requests library fetches the raw webpage content.

# %%
import requests
from bs4 import BeautifulSoup

# Specify the URL of the webpage you want to scrape
url = 'https://en.wikipedia.org/wiki/IBM'

# Spoof headers to mimic a browser
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36"
}

# Send request with headers
response = requests.get(url, headers=headers)
print(response) 

# Send an HTTP GET request to the webpage
response = requests.get(url , headers = headers)

# Store the HTML content in a variable
html_content = response.text

# Create a BeautifulSoup object to parse the HTML
soup = BeautifulSoup(html_content, 'html.parser')

# Display a snippet of the HTML content
print(html_content[:500])

links = soup.find_all('head')
#for link in links:
 #   print(link.text)
# Out:
# <Response [200]>
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vect

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Wikipedia page URL
url = "https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)"

# Spoof headers to mimic a browser
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36"
}

# Send request with headers
response = requests.get(url , headers=headers)
print(response)

# Parse HTML content
soup = BeautifulSoup(response.text, "lxml")
print(soup.title , soup.h3)

# Find the first GDP table
table = soup.find("table", {"class": "wikitable"})

# Extract rows
rows = table.find_all("tr")
data = []

for row in rows[1:]:
    cols = row.find_all(["th", "td"])
    cols = [ele.text.strip() for ele in cols]
    data.append(cols)

# Convert to DataFrame
df = pd.DataFrame(data)
print(df.head())
# Out:
# <Response [200]>
# <title>List of countries by GDP (nominal) - Wikipedia</title> None
#                0            1            2            3
# 0          World  113,795,678  111,326,370  100,834,796
# 1  United States   30,507,217   29,184,890   27,720,700
# 2     China[n 1]   19,231,705   18,743,803   17,794,782
# 3        Germany    4,744,804    4,659,929    4,525,704
# 4          India    4,187,017    3,912,686    3,575,778
